# %% [markdown]
# ## https://www.kaggle.com/datasets/kaggle/sf-salaries/data

# %%
import pandas as pd

# %%
data = pd.read_csv("Salaries.csv", low_memory=False)
# cols = ["BasePay", "OvertimePay", "OtherPay", "Benefits"]
# data[cols] = data[cols].apply(pd.to_numeric, errors="coerce")

# %% [markdown]
# C:\Users\kshit\AppData\Local\Temp\ipykernel_15088\2928864109.py:1: DtypeWarning: Columns (0: BasePay, 1: OvertimePay, 2: OtherPay, 3: Benefits, 4: Status) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Salaries.csv')

# %% [markdown]
# 1. Display top 10 rows of dataset

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# 2. Check last 10 rows of the dataset

# %%
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# 3. Find shape of our dataset

# %%
data.shape
# Out:
# (148654, 13)

# %%
print("Row",data.shape[0])
print("Column", data.shape[1])
# Out:
# Row 148654
# Column 13

# %% [markdown]
# 4. Getting Information About our Dataset

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  str
#  2   JobTitle          148654 non-null  str
#  3   BasePay           148049 non-null  str
#  4   OvertimePay       148654 non-null  str
#  5   OtherPay          148654 non-null  str
#  6   Benefits          112495 non-null  str
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  str
#  12  Status            38119 non-null   str
# dtypes: float64(3), int64(2), str(8)
# memory usage: 14.7 MB

# %% [markdown]
# 5. Check Null values in dataset

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# 6. Drop ID, Notes , Agency and Status Columns

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='str')

# %%
data.drop(['Id','Notes','Agency','Status'],axis=1, inplace=True)

# %% [markdown]
# Another way is this -> data = data.drop(['Id','Notes','Agency','Status'])

# %% [markdown]
# 7. Get overall stats of dataset

# %%
data.describe(include='all')
# Out:
#        EmployeeName          JobTitle BasePay OvertimePay OtherPay Benefits  \
# count        148654            148654  148049      148654   148654   112495
# unique       110811              2159  109724       66162    84243    98647
# top       Kevin Lee  Transit Operator     0.0         0.0      0.0      0.0
# freq             13              7036     872       57868    30068     1024
# mean            NaN               NaN     NaN         NaN      NaN      NaN
# std             NaN               NaN     NaN         NaN      NaN      NaN
# min             NaN               NaN     NaN         NaN      NaN      NaN
# 25%             NaN               NaN     NaN         NaN      NaN      NaN
# 50%             NaN               NaN     NaN         NaN      NaN      NaN
# 75%             NaN               NaN     NaN         NaN      NaN      NaN
# max             NaN               NaN     NaN         NaN      NaN      NaN
#
#              TotalPay  TotalPayBenefits           Year
# ...

# %% [markdown]
# 8. Find occurrance of the employee names (top 5)

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='str')

# %%
data['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Steven Lee      11
# William Wong    11
# Richard Lee     11
# KEVIN LEE        9
# Name: count, dtype: int64

# %% [markdown]
# 9. Find number of Unique Job Titles

# %%
data['JobTitle'].unique().value_counts().sum()
# Out:
# np.int64(2159)

# %%
data['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# 10. Total number of Job titles that contain captain

# %%
data['JobTitle'].str.contains('CAPTAIN',case=False).value_counts()
# Out:
# JobTitle
# False    148102
# True        552
# Name: count, dtype: int64

# %%
len(data[data['JobTitle'].str.contains('CAPTAIN',case=False)])
# Out:
# 552

# %% [markdown]
# 11. Display all the employee names from fire Dept

# %%
data[data['JobTitle'].str.contains('FIRE',case=False)]['EmployeeName']
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: str

# %% [markdown]
# 12. Find Minimum, Maximum and Average BasePay

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='str')

# %%
data["BasePay"] = pd.to_numeric(data["BasePay"], errors="coerce")

# %%
data['BasePay'].min()
# Out:
# np.float64(-166.01)

# %%
data["BasePay"].max()
# Out:
# np.float64(319275.01)

# %%
data["BasePay"].mean()
# Out:
# np.float64(66325.44884048769)

# %%
data["BasePay"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# 13. Replace 'Not Provided' in EmployeeName column to NaN

# %%
import numpy as np
data["EmployeeName"] = data["EmployeeName"].replace('Not provided',np.nan)
data["EmployeeName"]
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: str

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# 15. Drop the rows having missing values

# %%
data.drop(data[data.isnull().sum(axis=1)==5].index,axis=0,inplace=True)

# %% [markdown]
# 16. Find Job Title of Albert Pardini

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='str')

# %%
data[data["EmployeeName"] == 'Albert Pardini']['JobTitle']
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: str

# %% [markdown]
# 16. How much Albert Pardini make (include benefits)

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='str')

# %%
data[data["EmployeeName"] == 'Albert Pardini']["TotalPayBenefits"]
# Out:
# 36519    253995.29
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# 17. Display Name of the person having the highest BasePay

# %%
data[data["BasePay"].max()==data["BasePay"]]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: str

# %% [markdown]
# 18. Find Average BasePay of all employee per year

# %%
data.groupby('Year')["BasePay"].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# 19. Find Average BasePay of all employee per jobtitle

# %%
data.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# 20. Find Average BasePay of Employee Haivng Job Title Accountant

# %%
data[data['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# Out:
# np.float64(46643.172)

# %% [markdown]
# 21. Find 5 most commone jobs

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='str')

# %%
data['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64
